# %%
# Import the dependancies.
# %matplotlib inline
import pandas as pd
import gmaps
import requests
from IPython.display import display
import ipywidgets as widgets

# Import the API key.

from config import g_key

# %%
#city_data_df.dtypes

# %%
# Configure gmaps to use your Google API key.

gmaps.configure(api_key=g_key)

# %%
# Store the CSV file in Dataframe

city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df
# city_data_df = gmaps.datasets.load_dataset_as_df(city_data_df)
# city_data_df.head()
# Out:
#      City      City.1 Country      Lat       Lng  Max Temp  Humidity  \
# 0       0    Ondangwa     NaN -17.9167   15.9500     70.90        19
# 1       1      Talara      PE  -4.5772  -81.2719     63.79        89
# 2       2  Pingzhuang      CN  42.0372  119.2889     40.37        87
# 3       3     Rikitea      PF -23.1203 -134.9692     74.68        64
# 4       4   Saskylakh      RU  71.9167  114.0833     25.72        95
# ..    ...         ...     ...      ...       ...       ...       ...
# 558   558    Kedrovyy      RU  56.1667   91.8167     30.87        83
# 559   559     Klyuchi      RU  52.2667   79.1667     28.36        79
# 560   560      Ndende      GA  -2.4008   11.3581     71.53        98
# 561   561     Vilhena      BR -12.7406  -60.1458     69.33        94
# 562   562        Elko      US  41.0002 -115.5012     69.64        21
#
#      Cloudiness  Wind Speed
# 0            30        3.09
# 1            69       12.17
# 2           100       21.14
# 3            95        5.03
# 4           100       12.46
# ..          ...         ...
# 558          66        2.19
# 559           0        7.43
# 560         100        1.43
# 561          98        2.80
# 562          11       10.00
#
# [563 rows x 9 columns]

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
locations
max_temp
# Assign the figure variable.

fig = gmaps.figure() 
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
gmaps.figure()
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
jupyter nbextension enable --py gmaps
# Out:
#   File "C:\Users\avnit\AppData\Local\Temp\ipykernel_2900\2962148445.py", line 1
#     jupyter nbextension enable --py gmaps
#                       ^
# SyntaxError: invalid syntax
