# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats =  np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs =  np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates=list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
     city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
     if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32343a67e7d5d13a65c24721e66ffff0

# %%
city_url = url + "&q=" + "Boston"
weather_url=requests.get(city_url)
weather_json=weather_url.json()
weather_json
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 50.92,
#   'feels_like': 49.05,
#   'temp_min': 46.02,
#   'temp_max': 53.71,
#   'pressure': 1025,
#   'humidity': 71},
#  'visibility': 10000,
#  'wind': {'speed': 17.27, 'deg': 60},
#  'clouds': {'all': 75},
#  'dt': 1664845986,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1664793799,
#   'sunset': 1664835780},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Initialize an empty list to hold weather data

city_data = []

#Print the beginning of the logging.

print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.

record_count = 1
set_count = 1

# Loop through all the cities in the list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Climate Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | manado
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | te anau
# Processing Record 9 of Set 1 | emerald
# Processing Record 10 of Set 1 | kinkala
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | nanortalik
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | ambilobe
# Processing Record 15 of Set 1 | isangel
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | khatanga
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | sangar
# Processing Record 22 of Set 1 | balikpapan
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | alekseyevka
# Processing Record 26 of Set 1 | huaicheng
# Processing Record 27 of Set 1 | hasaki
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | mattru
# Processing Record 31 of Set 1 | the pas
# Processing Record 32 of Set 1 | vao
# Processing Record 33 of Set 1 | kletnya
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | praia
# Processing Record 36 of Set 1 | komsomolskiy
# Processing Record 37 of Set 1 | puerto el triunfo
# Processing Record 38 of Set 1 | omboue
# Processing Record 39 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | tiznit
# Processing Record 42 of Set 1 | pisco
# Processing Record 43 of Set 1 | fairbanks
# Processing Record 44 of Set 1 | clyde river
# Processing Record 45 of Set 1 | qaqortoq
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | vengerovo
# Processing Record 48 of Set 1 | hervey bay
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | quelimane
# Processing Record 2 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 2 | cidreira
# Processing Record 4 of Set 2 | vardo
# Processing Record 5 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 2 | quang ngai
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | saskylakh
# Processing Record 9 of Set 2 | kiruna
# Processing Record 10 of Set 2 | castro
# Processing Record 11 of Set 2 | maldonado
# Processing Record 12 of Set 2 | ilulissat
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | palmer
# Processing Record 15 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 2 | mahebourg
# Processing Record 17 of Set 2 | mbandaka
# Processing Record 18 of Set 2 | viransehir
# Processing Record 19 of Set 2 | ussel
# Processing Record 20 of Set 2 | falkenberg
# Processing Record 21 of Set 2 | upernavik
# Processing Record 22 of Set 2 | kosh-agach
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | tezu
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | xudat
# Processing Record 27 of Set 2 | najran
# Processing Record 28 of Set 2 | homer
# Processing Record 29 of Set 2 | alofi
# Processing Record 30 of Set 2 | batemans bay
# Processing Record 31 of Set 2 | casablanca
# Processing Record 32 of Set 2 | guerrero negro
# Processing Record 33 of Set 2 | abu samrah
# Processing Record 34 of Set 2 | camacha
# Processing Record 35 of Set 2 | cabo san lucas
# Processing Record 36 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 2 | souillac
# Processing Record 38 of Set 2 | chuy
# Processing Record 39 of Set 2 | chifeng
# Processing Record 40 of Set 2 | saint-ambroise
# Processing Record 41 of Set 2 | ahipara
# Processing Record 42 of Set 2 | poum
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | grindavik
# Processing Record 47 of Set 2 | belaya gora
# Processing Record 48 of Set 2 | salair
# Processing Record 49 of Set 2 | harper
# Processing Record 50 of Set 2 | berlevag
# Processing Record 1 of Set 3 | utmanzai
# Processing Record 2 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 3 of Set 3 | ostrovnoy
# Processing Record 4 of Set 3 | ancud
# Processing Record 5 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | port hardy
# Processing Record 8 of Set 3 | cortez
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | hithadhoo
# Processing Record 11 of Set 3 | tura
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | bud
# Processing Record 14 of Set 3 | iqaluit
# Processing Record 15 of Set 3 | saint george
# Processing Record 16 of Set 3 | saint anthony
# Processing Record 17 of Set 3 | ileza
# Processing Record 18 of Set 3 | bereda
# Processing Record 19 of Set 3 | hilo
# Processing Record 20 of Set 3 | anton lizardo
# Processing Record 21 of Set 3 | alice springs
# Processing Record 22 of Set 3 | skjervoy
# Processing Record 23 of Set 3 | mount pleasant
# Processing Record 24 of Set 3 | comodoro rivadavia
# Processing Record 25 of Set 3 | isiro
# Processing Record 26 of Set 3 | gobabis
# Processing Record 27 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 3 | ulaangom
# Processing Record 29 of Set 3 | penzance
# Processing Record 30 of Set 3 | koupela
# Processing Record 31 of Set 3 | port shepstone
# Processing Record 32 of Set 3 | aklavik
# Processing Record 33 of Set 3 | pauini
# Processing Record 34 of Set 3 | dicabisagan
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | carupano
# Processing Record 37 of Set 3 | kindia
# Processing Record 38 of Set 3 | ijero
# Processing Record 39 of Set 3 | kaitangata
# Processing Record 40 of Set 3 | salalah
# Processing Record 41 of Set 3 | lang suan
# Processing Record 42 of Set 3 | avarua
# Processing Record 43 of Set 3 | waipawa
# Processing Record 44 of Set 3 | hirara
# Processing Record 45 of Set 3 | ardakan
# Processing Record 46 of Set 3 | athabasca
# Processing Record 47 of Set 3 | bilma
# Processing Record 48 of Set 3 | syracuse
# Processing Record 49 of Set 3 | klaksvik
# Processing Record 50 of Set 3 | severo-kurilsk
# Processing Record 1 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 4 | strezhevoy
# Processing Record 3 of Set 4 | clarksburg
# Processing Record 4 of Set 4 | vostok
# Processing Record 5 of Set 4 | wairoa
# Processing Record 6 of Set 4 | synya
# Processing Record 7 of Set 4 | kojnare
# Processing Record 8 of Set 4 | aykhal
# Processing Record 9 of Set 4 | borogontsy
# Processing Record 10 of Set 4 | sitka
# Processing Record 11 of Set 4 | bredasdorp
# Processing Record 12 of Set 4 | qianan
# Processing Record 13 of Set 4 | sinjai
# Processing Record 14 of Set 4 | andevoranto
# City not found. Skipping...
# Processing Record 15 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 16 of Set 4 | lagoa
# Processing Record 17 of Set 4 | la ronge
# Processing Record 18 of Set 4 | carnarvon
# Processing Record 19 of Set 4 | marsa matruh
# Processing Record 20 of Set 4 | mathbaria
# Processing Record 21 of Set 4 | sobolevo
# Processing Record 22 of Set 4 | parabel
# Processing Record 23 of Set 4 | esperance
# Processing Record 24 of Set 4 | bandarbeyla
# Processing Record 25 of Set 4 | khani
# Processing Record 26 of Set 4 | tommot
# Processing Record 27 of Set 4 | norman wells
# Processing Record 28 of Set 4 | mount gambier
# Processing Record 29 of Set 4 | port alfred
# Processing Record 30 of Set 4 | west lafayette
# Processing Record 31 of Set 4 | el dorado
# Processing Record 32 of Set 4 | chebenki
# Processing Record 33 of Set 4 | saldanha
# Processing Record 34 of Set 4 | maragogi
# Processing Record 35 of Set 4 | faya
# Processing Record 36 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 4 | bridlington
# Processing Record 38 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 4 | krasnoselkup
# Processing Record 40 of Set 4 | bulgan
# Processing Record 41 of Set 4 | pimentel
# Processing Record 42 of Set 4 | pacific grove
# Processing Record 43 of Set 4 | tiksi
# Processing Record 44 of Set 4 | zlatoustovsk
# City not found. Skipping...
# Processing Record 45 of Set 4 | fort nelson
# Processing Record 46 of Set 4 | leningradskiy
# Processing Record 47 of Set 4 | kahului
# Processing Record 48 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 4 | narbonne
# Processing Record 50 of Set 4 | taoudenni
# Processing Record 1 of Set 5 | rustenburg
# Processing Record 2 of Set 5 | fortuna
# Processing Record 3 of Set 5 | manzhouli
# Processing Record 4 of Set 5 | key west
# Processing Record 5 of Set 5 | caninde
# Processing Record 6 of Set 5 | northam
# Processing Record 7 of Set 5 | mataura
# Processing Record 8 of Set 5 | ust-tsilma
# Processing Record 9 of Set 5 | broome
# Processing Record 10 of Set 5 | yumen
# Processing Record 11 of Set 5 | baruun-urt
# Processing Record 12 of Set 5 | longyearbyen
# Processing Record 13 of Set 5 | sri aman
# Processing Record 14 of Set 5 | ayagoz
# Processing Record 15 of Set 5 | russell
# Processing Record 16 of Set 5 | mino
# Processing Record 17 of Set 5 | luderitz
# Processing Record 18 of Set 5 | bengkulu
# Processing Record 19 of Set 5 | namibe
# Processing Record 20 of Set 5 | acapulco
# Processing Record 21 of Set 5 | lexington
# Processing Record 22 of Set 5 | pangnirtung
# Processing Record 23 of Set 5 | port elizabeth
# Processing Record 24 of Set 5 | barrow
# Processing Record 25 of Set 5 | georgetown
# Processing Record 26 of Set 5 | christchurch
# Processing Record 27 of Set 5 | whitianga
# Processing Record 28 of Set 5 | san cristobal
# Processing Record 29 of Set 5 | canete
# Processing Record 30 of Set 5 | lakes entrance
# Processing Record 31 of Set 5 | deh rawud
# City not found. Skipping...
# Processing Record 32 of Set 5 | cuauhtemoc
# Processing Record 33 of Set 5 | boden
# Processing Record 34 of Set 5 | gimli
# Processing Record 35 of Set 5 | salinas
# Processing Record 36 of Set 5 | bathsheba
# Processing Record 37 of Set 5 | lavrentiya
# Processing Record 38 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 5 | necochea
# Processing Record 40 of Set 5 | whyalla
# Processing Record 41 of Set 5 | timbiras
# Processing Record 42 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 5 | boca do acre
# Processing Record 44 of Set 5 | yar-sale
# Processing Record 45 of Set 5 | japura
# Processing Record 46 of Set 5 | sola
# Processing Record 47 of Set 5 | de aar
# Processing Record 48 of Set 5 | scalloway
# City not found. Skipping...
# Processing Record 49 of Set 5 | shelton
# Processing Record 50 of Set 5 | parasia
# Processing Record 1 of Set 6 | ciudad valles
# Processing Record 2 of Set 6 | yayva
# Processing Record 3 of Set 6 | walvis bay
# Processing Record 4 of Set 6 | tessalit
# Processing Record 5 of Set 6 | shiyan
# Processing Record 6 of Set 6 | port augusta
# Processing Record 7 of Set 6 | san rafael
# Processing Record 8 of Set 6 | great bend
# Processing Record 9 of Set 6 | naraina
# Processing Record 10 of Set 6 | alta floresta
# Processing Record 11 of Set 6 | nakhon phanom
# Processing Record 12 of Set 6 | daxian
# City not found. Skipping...
# Processing Record 13 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 6 | mazagao
# Processing Record 15 of Set 6 | cabreuva
# Processing Record 16 of Set 6 | murdochville
# Processing Record 17 of Set 6 | ambalavao
# Processing Record 18 of Set 6 | mao
# Processing Record 19 of Set 6 | butaritari
# Processing Record 20 of Set 6 | isla vista
# Processing Record 21 of Set 6 | ketchikan
# Processing Record 22 of Set 6 | vila franca do campo
# Processing Record 23 of Set 6 | shitkino
# Processing Record 24 of Set 6 | colquechaca
# Processing Record 25 of Set 6 | axim
# Processing Record 26 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 6 | beringovskiy
# Processing Record 28 of Set 6 | launceston
# Processing Record 29 of Set 6 | bac can
# City not found. Skipping...
# Processing Record 30 of Set 6 | kharsia
# Processing Record 31 of Set 6 | ponta do sol
# Processing Record 32 of Set 6 | cuamba
# Processing Record 33 of Set 6 | goedereede
# Processing Record 34 of Set 6 | boli
# Processing Record 35 of Set 6 | gatton
# Processing Record 36 of Set 6 | karaton
# Processing Record 37 of Set 6 | mandurah
# Processing Record 38 of Set 6 | kununurra
# Processing Record 39 of Set 6 | george
# Processing Record 40 of Set 6 | bundaberg
# Processing Record 41 of Set 6 | sabang
# Processing Record 42 of Set 6 | mitsamiouli
# Processing Record 43 of Set 6 | grenaa
# Processing Record 44 of Set 6 | ternate
# Processing Record 45 of Set 6 | aquidauana
# Processing Record 46 of Set 6 | bay roberts
# Processing Record 47 of Set 6 | almaznyy
# Processing Record 48 of Set 6 | karratha
# Processing Record 49 of Set 6 | los llanos de aridane
# Processing Record 50 of Set 6 | bafut
# Processing Record 1 of Set 7 | praya
# Processing Record 2 of Set 7 | doka
# Processing Record 3 of Set 7 | alpena
# Processing Record 4 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 7 | nhlangano
# Processing Record 6 of Set 7 | sao joao da barra
# Processing Record 7 of Set 7 | talnakh
# Processing Record 8 of Set 7 | stabat
# Processing Record 9 of Set 7 | basco
# Processing Record 10 of Set 7 | solnechnyy
# Processing Record 11 of Set 7 | yeppoon
# Processing Record 12 of Set 7 | richards bay
# Processing Record 13 of Set 7 | yerbogachen
# Processing Record 14 of Set 7 | redding
# Processing Record 15 of Set 7 | allapalli
# Processing Record 16 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 7 | vilhena
# Processing Record 18 of Set 7 | dali
# Processing Record 19 of Set 7 | pitimbu
# Processing Record 20 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 7 | noumea
# Processing Record 22 of Set 7 | kamaishi
# Processing Record 23 of Set 7 | mazara del vallo
# Processing Record 24 of Set 7 | lisakovsk
# Processing Record 25 of Set 7 | carutapera
# Processing Record 26 of Set 7 | victoria
# Processing Record 27 of Set 7 | lephepe
# City not found. Skipping...
# Processing Record 28 of Set 7 | huangzhou
# Processing Record 29 of Set 7 | dayong
# Processing Record 30 of Set 7 | tavda
# Processing Record 31 of Set 7 | sioux lookout
# Processing Record 32 of Set 7 | lincoln
# Processing Record 33 of Set 7 | umm lajj
# Processing Record 34 of Set 7 | college
# Processing Record 35 of Set 7 | lorengau
# Processing Record 36 of Set 7 | denpasar
# Processing Record 37 of Set 7 | conceicao do araguaia
# Processing Record 38 of Set 7 | husavik
# Processing Record 39 of Set 7 | del rio
# Processing Record 40 of Set 7 | iasmos
# Processing Record 41 of Set 7 | vanavara
# Processing Record 42 of Set 7 | velten
# Processing Record 43 of Set 7 | salta
# Processing Record 44 of Set 7 | karnobat
# Processing Record 45 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 46 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 7 | fernie
# Processing Record 48 of Set 7 | veyrier
# Processing Record 49 of Set 7 | celestun
# Processing Record 50 of Set 7 | vale
# Processing Record 1 of Set 8 | port hedland
# Processing Record 2 of Set 8 | pyapon
# Processing Record 3 of Set 8 | imbituba
# Processing Record 4 of Set 8 | puerto plata
# Processing Record 5 of Set 8 | elko
# Processing Record 6 of Set 8 | lao cai
# Processing Record 7 of Set 8 | awjilah
# Processing Record 8 of Set 8 | liverpool
# Processing Record 9 of Set 8 | vila velha
# Processing Record 10 of Set 8 | paraisopolis
# Processing Record 11 of Set 8 | port lincoln
# Processing Record 12 of Set 8 | colares
# Processing Record 13 of Set 8 | balvanesti
# Processing Record 14 of Set 8 | poya
# Processing Record 15 of Set 8 | hambantota
# Processing Record 16 of Set 8 | manta
# Processing Record 17 of Set 8 | spokane
# Processing Record 18 of Set 8 | tiarei
# Processing Record 19 of Set 8 | nosy varika
# Processing Record 20 of Set 8 | otorohanga
# Processing Record 21 of Set 8 | oneonta
# Processing Record 22 of Set 8 | bridgetown
# Processing Record 23 of Set 8 | krasnyy chikoy
# Processing Record 24 of Set 8 | menongue
# Processing Record 25 of Set 8 | katsuura
# Processing Record 26 of Set 8 | hami
# Processing Record 27 of Set 8 | riyadh
# Processing Record 28 of Set 8 | tres passos
# Processing Record 29 of Set 8 | avera
# Processing Record 30 of Set 8 | bawku
# Processing Record 31 of Set 8 | constitucion
# Processing Record 32 of Set 8 | eyrarbakki
# Processing Record 33 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 34 of Set 8 | sosnovo
# Processing Record 35 of Set 8 | sao filipe
# Processing Record 36 of Set 8 | praia da vitoria
# Processing Record 37 of Set 8 | hamilton
# Processing Record 38 of Set 8 | novoagansk
# Processing Record 39 of Set 8 | vieques
# Processing Record 40 of Set 8 | ayios matthaios
# City not found. Skipping...
# Processing Record 41 of Set 8 | kodiak
# Processing Record 42 of Set 8 | mutis
# Processing Record 43 of Set 8 | beruni
# City not found. Skipping...
# Processing Record 44 of Set 8 | geraldton
# Processing Record 45 of Set 8 | kisangani
# Processing Record 46 of Set 8 | dongsheng
# Processing Record 47 of Set 8 | boyolangu
# Processing Record 48 of Set 8 | matamoros
# Processing Record 49 of Set 8 | tres arroyos
# Processing Record 50 of Set 8 | balkhash
# Processing Record 1 of Set 9 | hanyang
# Processing Record 2 of Set 9 | mananjary
# Processing Record 3 of Set 9 | baltasi
# Processing Record 4 of Set 9 | klyuchi
# Processing Record 5 of Set 9 | pevek
# Processing Record 6 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 7 of Set 9 | hovd
# Processing Record 8 of Set 9 | bambous virieux
# Processing Record 9 of Set 9 | dzerzhinskoye
# Processing Record 10 of Set 9 | airai
# Processing Record 11 of Set 9 | esmeraldas
# Processing Record 12 of Set 9 | muros
# Processing Record 13 of Set 9 | lodja
# Processing Record 14 of Set 9 | bethel
# Processing Record 15 of Set 9 | valer
# Processing Record 16 of Set 9 | saint-augustin
# Processing Record 17 of Set 9 | novogagatli
# Processing Record 18 of Set 9 | mirnyy
# Processing Record 19 of Set 9 | flinders
# Processing Record 20 of Set 9 | kenai
# Processing Record 21 of Set 9 | qasigiannguit
# Processing Record 22 of Set 9 | thinadhoo
# Processing Record 23 of Set 9 | cholet
# Processing Record 24 of Set 9 | chokurdakh
# Processing Record 25 of Set 9 | jumla
# Processing Record 26 of Set 9 | narsaq
# Processing Record 27 of Set 9 | kamakwie
# Processing Record 28 of Set 9 | sakakah
# Processing Record 29 of Set 9 | pokaran
# Processing Record 30 of Set 9 | leh
# Processing Record 31 of Set 9 | half moon bay
# Processing Record 32 of Set 9 | ashland
# Processing Record 33 of Set 9 | daye
# Processing Record 34 of Set 9 | puerto ayacucho
# Processing Record 35 of Set 9 | grafton
# Processing Record 36 of Set 9 | clifton
# Processing Record 37 of Set 9 | abu dhabi
# Processing Record 38 of Set 9 | chlorakas
# Processing Record 39 of Set 9 | xai-xai
# Processing Record 40 of Set 9 | bujaru
# Processing Record 41 of Set 9 | bilibino
# Processing Record 42 of Set 9 | rio grande
# Processing Record 43 of Set 9 | great falls
# Processing Record 44 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 9 | xuanhua
# Processing Record 46 of Set 9 | sungaipenuh
# Processing Record 47 of Set 9 | itarema
# Processing Record 48 of Set 9 | belmonte
# Processing Record 49 of Set 9 | ventspils
# Processing Record 50 of Set 9 | kupang
# Processing Record 1 of Set 10 | provost
# Processing Record 2 of Set 10 | pringsewu
# Processing Record 3 of Set 10 | monzon
# Processing Record 4 of Set 10 | banda aceh
# Processing Record 5 of Set 10 | machali
# Processing Record 6 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 7 of Set 10 | jambi
# Processing Record 8 of Set 10 | chapais
# Processing Record 9 of Set 10 | bam
# Processing Record 10 of Set 10 | rio claro
# Processing Record 11 of Set 10 | sur
# Processing Record 12 of Set 10 | ascension
# Processing Record 13 of Set 10 | kavieng
# Processing Record 14 of Set 10 | nemuro
# Processing Record 15 of Set 10 | kalawit
# Processing Record 16 of Set 10 | rongcheng
# Processing Record 17 of Set 10 | okhotsk
# Processing Record 18 of Set 10 | bom jesus
# Processing Record 19 of Set 10 | simbahan
# Processing Record 20 of Set 10 | saint-paul
# Processing Record 21 of Set 10 | kargasok
# Processing Record 22 of Set 10 | buraydah
# Processing Record 23 of Set 10 | inverell
# Processing Record 24 of Set 10 | bataipora
# Processing Record 25 of Set 10 | paris
# Processing Record 26 of Set 10 | nalut
# Processing Record 27 of Set 10 | baghdad
# Processing Record 28 of Set 10 | auki
# Processing Record 29 of Set 10 | innisfail
# Processing Record 30 of Set 10 | cayenne
# Processing Record 31 of Set 10 | taraz
# Processing Record 32 of Set 10 | lompoc
# Processing Record 33 of Set 10 | tuatapere
# Processing Record 34 of Set 10 | bubaque
# Processing Record 35 of Set 10 | marfino
# Processing Record 36 of Set 10 | ojinaga
# Processing Record 37 of Set 10 | duku
# Processing Record 38 of Set 10 | tambura
# Processing Record 39 of Set 10 | oranjemund
# Processing Record 40 of Set 10 | kibondo
# Processing Record 41 of Set 10 | neverkino
# Processing Record 42 of Set 10 | sergeyevka
# Processing Record 43 of Set 10 | nouadhibou
# Processing Record 44 of Set 10 | chabahar
# Processing Record 45 of Set 10 | cumberland
# Processing Record 46 of Set 10 | mount isa
# Processing Record 47 of Set 10 | djibo
# Processing Record 48 of Set 10 | cherskiy
# Processing Record 49 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 10 | nova serrana
# Processing Record 1 of Set 11 | edd
# Processing Record 2 of Set 11 | bollnas
# Processing Record 3 of Set 11 | okoneshnikovo
# Processing Record 4 of Set 11 | montevideo
# Processing Record 5 of Set 11 | alyangula
# Processing Record 6 of Set 11 | trebukhiv
# Processing Record 7 of Set 11 | yinchuan
# Processing Record 8 of Set 11 | baglung
# Processing Record 9 of Set 11 | canutama
# Processing Record 10 of Set 11 | urdoma
# Processing Record 11 of Set 11 | adet
# Processing Record 12 of Set 11 | roma
# Processing Record 13 of Set 11 | chagoda
# Processing Record 14 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 15 of Set 11 | matay
# Processing Record 16 of Set 11 | voyvozh
# Processing Record 17 of Set 11 | kondopoga
# Processing Record 18 of Set 11 | thanh hoa
# Processing Record 19 of Set 11 | ulaanbaatar
# Processing Record 20 of Set 11 | zeerust
# Processing Record 21 of Set 11 | belle fourche
# Processing Record 22 of Set 11 | teahupoo
# Processing Record 23 of Set 11 | samarai
# Processing Record 24 of Set 11 | hofn
# Processing Record 25 of Set 11 | saint-joseph
# Processing Record 26 of Set 11 | bintulu
# Processing Record 27 of Set 11 | henties bay
# Processing Record 28 of Set 11 | bonthe
# Processing Record 29 of Set 11 | luba
# Processing Record 30 of Set 11 | mahibadhoo
# Processing Record 31 of Set 11 | vestmannaeyjar
# Processing Record 32 of Set 11 | qui nhon
# Processing Record 33 of Set 11 | bloemfontein
# Processing Record 34 of Set 11 | thessalon
# Processing Record 35 of Set 11 | jieshi
# Processing Record 36 of Set 11 | ola
# Processing Record 37 of Set 11 | asfi
# Processing Record 38 of Set 11 | namatanai
# Processing Record 39 of Set 11 | muravlenko
# Processing Record 40 of Set 11 | manggar
# Processing Record 41 of Set 11 | nome
# Processing Record 42 of Set 11 | port blair
# Processing Record 43 of Set 11 | vanimo
# Processing Record 44 of Set 11 | tocopilla
# Processing Record 45 of Set 11 | podyuga
# Processing Record 46 of Set 11 | moerai
# Processing Record 47 of Set 11 | burntwood
# Processing Record 48 of Set 11 | buta
# Processing Record 49 of Set 11 | abalak
# Processing Record 50 of Set 11 | coquimbo
# Processing Record 1 of Set 12 | kruisfontein
# Processing Record 2 of Set 12 | whitehorse
# Processing Record 3 of Set 12 | kalmunai
# Processing Record 4 of Set 12 | paita
# Processing Record 5 of Set 12 | roebourne
# Processing Record 6 of Set 12 | nabire
# Processing Record 7 of Set 12 | valkeala
# Processing Record 8 of Set 12 | benguela
# Processing Record 9 of Set 12 | andenes
# Processing Record 10 of Set 12 | illapel
# Processing Record 11 of Set 12 | kingman
# Processing Record 12 of Set 12 | alghero
# Processing Record 13 of Set 12 | krasnyy yar
# Processing Record 14 of Set 12 | kotovo
# Processing Record 15 of Set 12 | outram
# Processing Record 16 of Set 12 | nadvoitsy
# Processing Record 17 of Set 12 | oksfjord
# Processing Record 18 of Set 12 | great yarmouth
# Processing Record 19 of Set 12 | okha
# Processing Record 20 of Set 12 | miandrivazo
# Processing Record 21 of Set 12 | katobu
# Processing Record 22 of Set 12 | saint-pierre
# Processing Record 23 of Set 12 | voi
# Processing Record 24 of Set 12 | malartic
# Processing Record 25 of Set 12 | am timan
# Processing Record 26 of Set 12 | kerman
# Processing Record 27 of Set 12 | mehamn
# Processing Record 28 of Set 12 | kulhudhuffushi
# Processing Record 29 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 12 | general roca
# Processing Record 31 of Set 12 | novikovo
# Processing Record 32 of Set 12 | catalina
# Processing Record 33 of Set 12 | goderich
# Processing Record 34 of Set 12 | miri
# Processing Record 35 of Set 12 | lindi
# Processing Record 36 of Set 12 | shetpe
# Processing Record 37 of Set 12 | tual
# Processing Record 38 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 12 | faanui
# Processing Record 40 of Set 12 | gidole
# Processing Record 41 of Set 12 | meulaboh
# Processing Record 42 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 12 | chepareria
# Processing Record 44 of Set 12 | coihaique
# Processing Record 45 of Set 12 | batticaloa
# Processing Record 46 of Set 12 | yarmouth
# Processing Record 47 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 12 | sisophon
# Processing Record 49 of Set 12 | bata
# Processing Record 50 of Set 12 | aswan
# Processing Record 1 of Set 13 | timizart
# Processing Record 2 of Set 13 | naugarzan
# City not found. Skipping...
# Processing Record 3 of Set 13 | tarakan
# Processing Record 4 of Set 13 | emirdag
# Processing Record 5 of Set 13 | sault sainte marie
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 562

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df =  pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Busselton -33.6500  115.3333     59.76        63           0       13.33
# 1   Tasiilaq  65.6145  -37.6368     34.57        98         100        8.57
# 2  Jamestown  42.0970  -79.2353     47.84        66           0        5.75
# 3     Atuona  -9.8000 -139.0333     76.39        78          28       19.46
# 4     Manado   1.4870  124.8455     83.17        78          40        6.91
#
#   Country Climate Description
# 0      AU           clear sky
# 1      GL          light snow
# 2      US           clear sky
# 3      PF    scattered clouds
# 4      ID          light rain

# %%
# Display sample data
city_data_df
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Busselton -33.6500  115.3333     59.76        63           0
# 1              Tasiilaq  65.6145  -37.6368     34.57        98         100
# 2             Jamestown  42.0970  -79.2353     47.84        66           0
# 3                Atuona  -9.8000 -139.0333     76.39        78          28
# 4                Manado   1.4870  124.8455     83.17        78          40
# ..                  ...      ...       ...       ...       ...         ...
# 557               Aswan  24.0934   32.9070     81.66        38           0
# 558            Timizart  36.8000    4.2667     70.97        61         100
# 559             Tarakan   3.3000  117.6333     85.50        74          20
# 560             Emirdag  39.0197   31.1500     49.03        81           0
# 561  Sault Sainte Marie  46.5168  -84.3333     52.36        87           0
#
#      Wind Speed Country Climate Description
# 0         13.33      AU           clear sky
# 1          8.57      GL          light snow
# 2          5.75      US           clear sky
# 3         19.46      PF    scattered clouds
# 4          6.91      ID          light rain
# ..          ...     ...                 ...
# 557       10.45      EG           clear sky
# 558        1.03      DZ     overcast clouds
# 559        4.61      ID          few clouds
# 560        3.18      TR           clear sky
# 561        0.00      CA           clear sky
#
# [562 rows x 9 columns]

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Climate Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_city_data = [ "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed","Climate Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_city_data]


# Display sample data
city_data_df
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Busselton      AU -33.6500  115.3333     59.76        63
# 1              Tasiilaq      GL  65.6145  -37.6368     34.57        98
# 2             Jamestown      US  42.0970  -79.2353     47.84        66
# 3                Atuona      PF  -9.8000 -139.0333     76.39        78
# 4                Manado      ID   1.4870  124.8455     83.17        78
# ..                  ...     ...      ...       ...       ...       ...
# 557               Aswan      EG  24.0934   32.9070     81.66        38
# 558            Timizart      DZ  36.8000    4.2667     70.97        61
# 559             Tarakan      ID   3.3000  117.6333     85.50        74
# 560             Emirdag      TR  39.0197   31.1500     49.03        81
# 561  Sault Sainte Marie      CA  46.5168  -84.3333     52.36        87
#
#      Cloudiness  Wind Speed Climate Description
# 0             0       13.33           clear sky
# 1           100        8.57          light snow
# 2             0        5.75           clear sky
# 3            28       19.46    scattered clouds
# 4            40        6.91          light rain
# ..          ...         ...                 ...
# 557           0       10.45           clear sky
# 558         100        1.03     overcast clouds
# 559          20        4.61          few clouds
# 560           0        3.18           clear sky
# 561           0        0.00           clear sky
#
# [562 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Climate Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weather_data/cities1.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file,index_label="City")
